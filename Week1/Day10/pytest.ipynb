# %% [markdown]
# ## pytest
#
# ### **To install the latest version of pytest, execute the following command**
#
# #### **pip install pytest**

# %% [markdown]
# ### It works with only .py extension
#
# #### Run the test using the following command − **pytest**

# %%
import math 
def test_sqrt():
    num = 25
    assert math.sqrt(num) == 5

def testsquare():
    num = 7
    assert 7*7 == 40

def testequality():
    assert 10 == 10

# %% [markdown]
# test_square.py .F
# ============================================== FAILURES
# ==============================================
# ______________________________________________ testsquare
# _____________________________________________
#    def testsquare():
#    num=7
# >  assert 7*7 == 40
# E  assert (7 * 7) == 40
# test_square.py:9: AssertionError
# ================================= 1 failed, 2 passed in 0.06 seconds
# =================================

# %% [markdown]
# ### Now, execute the **python -v** command and see the result again

# %%
import math 
def test_sqrt():
    num = 25
    assert math.sqrt(num) == 5

def testsquare():
    num = 7
    assert 7*7 == 40

def testequality():
    assert 10 == 11

# %% [markdown]
# collected 3
# items
#
# test_unit.py::test_sqrt PASSED                                                                                                                           [ 33%]
# test_unit.py::testsquare FAILED                                                                                                                          [ 66%]
# test_unit.py::testequality FAILED                                                                                                                        [100%]
#
# ============================ FAILURES ==========================
# ____________________________ testsquare ___________________________
#
#     def testsquare():
#         num = 7
# >       assert 7*7 == 40
# E       assert (7 * 7) == 40
#
# test_unit.py:22: AssertionError
# _________________________ testequality _______________________
#
#     def testequality():
# >       assert 10 == 11
# E       assert 10 == 11
#
# test_unit.py:25: AssertionError
# ========================== short test summary info =======================
# FAILED test_unit.py::testsquare - assert (7 * 7) == 40
# FAILED test_unit.py::testequality - assert 10 == 11
# ====================== 2 failed, 1 passed in 0.17s ==================

# %% [markdown]
# ## **Note** − pytest command will execute all the files of format test_* or *_test in the current directory and subdirectories.

# %% [markdown]
# ##### To execute the tests from a specific file, use the following syntax −
#
# ##### pytest \<filename\> -v

# %% [markdown]
# ##### Now, run the following command −
#
# ##### pytest test_unit.py -v

# %% [markdown]
# ##### Note − The name of the test function should still start with **test**.

# %%
import pytest
@pytest.mark.xfail
