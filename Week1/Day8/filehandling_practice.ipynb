# %%
with open("myfile2.txt","a+") as file1:
    lines = ["this content is add by the writelines:","second line is add by writelines "]
    file1.writelines(lines)

# %%
with open("myfile3.txt","a") as file1:
    print(file1.tell())
# Out:
# 50

# %% [markdown]
# ### Read text file and count the numbers of Characters

# %%
with open("myfile3.txt","r") as file1:
    content = file1.read()
    count = 0
    for i in content:
        count+=1
    print(count)    
    #count the characters
# Out:
# 50

# %% [markdown]
# ### read text file and count the numbers of lines

# %%
with open("myfile2.txt","r") as file1:
    content = file1.readlines()
    count = 0
    for i in content:
        count+=1
    print(count)    
    #count the lines
# Out:
# 5

# %% [markdown]
# ### Read text file and count the numbers of words

# %%
with open("myfile2.txt","r") as file1:
    content = file1.readlines()
    total_count = 0
    for i in content:
        list_of_words = i.split()
        count = 0
        for j in list_of_words:
            count+=1
        total_count+=count    
    print(total_count)        


        
    #count word from text file
# Out:
# 35

# %%
with open("myfile2.txt","r") as file1:
    list_of_words = file1.read().split()
    count = 0
    for i in list_of_words:
        count+=1
    print(count)
# Out:
# 35

# %% [markdown]
# #### Count the unique words from file

# %%
with open("myfile2.txt","r") as file1:
    unique_words = []
    line = file1.read().split()
    for i in line:
        if i not in unique_words:
            unique_words.append(i)
    print(len(unique_words))
# Out:
# 24

# %%
import os
name = "myfile2.txt"
if os.path.isfile(name):
    print("this is a file type" )
else:
    print("unknown file type")
# Out:
# this is a file type
