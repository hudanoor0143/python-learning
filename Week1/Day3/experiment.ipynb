# %%
def calc_sum(a,b):#give two Parameter in Function
    sum = a+b
    print(sum) 
calc_sum(10,20) #call the funtion by function name giving two parameter
calc_sum(30,40) #intead of writing full code we just call with argument

#decrease redundent ,repetetion
# Out:
# 30
# 70

# %%
def print_hello():
    print("hello")
output = print_hello() #output store the print_hello value
print(output)  #print(none) because it stores the return value when we write return "hello"
# Out:
# hello
# None

# %%
#built_in_function
#print() 
print("huda","noor") #seperate it with space
print("huda") #end = "\n" this will automatically print in the next line
# Out:
# huda noor
# huda

# %%
#if we don't want to print in the next line we have to give space in the end 
#example
print("huda",end = " ") 
print("noor")
# Out:
# huda noor

# %%
#default parameter
def cal_prod(a=2,b=3):
    print(a*b)
cal_prod()
# Out:
# 6

# %%
#default parameter starts from right side otherwise it will give error 
def cal_prod(a,b=3,c=3):
    print(a*b*c)
cal_prod(1)
# Out:
# 9

# %%
#print the length of a list(list is a parameter )
list1= ["huda","mehr","shizi"]
list2 = ["mehr","ammara","huda"]
def print_len(list):
    print(len(list))

print_len(list1)  
print_len(list2)
# Out:
# 3
# 3

# %%
#print the elenet of a single lis in a single line 
list1= ["huda","mehr","shizi","ammara"]
def single_line(list1):
    for item in list1: #loop continue for all items of the list
        print(item,end=" ") #use end with space to print one line 
single_line(list1)
# Out:
# huda mehr shizi ammara

# %%
#find factorial of n parameter  without function
n = 5
fac = 1
for i in range(1,n+1):#n+1 is given bcz range exclude last value
    fac*= i #every time value of fac variable by i value
print(fac)
# Out:
# 120

# %%
#find factorial of n parameter  with function
#it is effective if we want to take a factorial of different number we no need to write code again 
#we just call function with different arguments
def cal_fac(n):
    fac = 1 
    for i in range(1,n+1):
        fac*=i
    print(fac)
cal_fac(5)
# Out:
# 120

# %%
#return Even or Odd string 
def evn_odd(n):
    if n%2==0:
        print("This Number Is Even")
    else:
        print("Number Is Odd")  
#funcoin call with argument
evn_odd(5)    
evn_odd(6)
# Out:
# Number Is Odd
# This Number Is Even

# %%
#shoe number 5 4 3 2 1 by recursion
#we can do it wth the loop but do it with recursion
def show(n):
    if n == 0: #base case
        return
    print(n)
    show(n-1) # n-1 will remain continue we have to give base case to stop
show(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#Find Factoria With recursion
def fac(n): 
    #base case
    if (n==0 or n==1):
        return 1
    else:
        return n*fac(n-1)
print(fac(5))
# Out:
# 120

# %%
#calculate the sun of n natural numbers by recursion 
def sum(n):
    if n<=0:
        return 0
    else:
        return n+sum(n-1)
print(sum(1))
# Out:
# 1

# %%
#Recursion print all element in a list by using index
def list_element(list,indx=0):#indx is defaul parameter
    if (indx == len(list)): #base case to stp recursive call
        return
    print(list[indx]) # print item by index 
    list_element(list,indx+1) #recursive call ..increment in index
names = ["mehr","shizi","ammara","huda"]

list_element(names)
# Out:
# mehr
# shizi
# ammara
# huda
